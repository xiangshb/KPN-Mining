# %%
from network.kpm_evaluation_metrics_cross import KPMEvaluator
from utils.params import KPNParams
kpn_parms = KPNParams(
    disciplines=[],
    row_normalize=False,
    threshold_mode='value_count_limit',
    quantile_threshold=0.65,
    cvm_threshold=0.95,
    cfm_threshold=0.2,
    matrix_filter=True,
    matrix_imshow=False,
    graph_show=True,
    layout="graphviz",
    save_kpn=True,
    old_matrix_version=False
)
generator = KPMEvaluator(kpn_parms = kpn_parms, sub_discipline = False)
generator.cvm_cfm_sensitivity_analysis()
# Out:
# Successfully loaded Word2Vec model with dimension: 24
# Successfully loaded Word2Vec model with dimension: 24
# Successfully loaded Word2Vec model with dimension: 24
# CVM=0.9, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2926
# CVM=0.9, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3689
# CVM=0.9, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3854
# CVM=0.9, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3912
# CVM=0.9, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3935
# CVM=0.91, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2760
# CVM=0.91, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3523
# CVM=0.91, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3688
# CVM=0.91, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3746
# CVM=0.91, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3769
# CVM=0.92, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2579
# CVM=0.92, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3342
# CVM=0.92, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3507
# CVM=0.92, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3565
# CVM=0.92, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3588
# CVM=0.93, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2378
# CVM=0.93, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3141
# CVM=0.93, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3306
# CVM=0.93, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3364
# CVM=0.93, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3387
# CVM=0.94, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2154
# CVM=0.94, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2917
# CVM=0.94, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3082
# CVM=0.94, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3140
# CVM=0.94, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=3163
# CVM=0.95, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=1903
# CVM=0.95, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2666
# CVM=0.95, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2831
# CVM=0.95, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2889
# CVM=0.95, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=2912
# CVM=0.9, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=6253
# CVM=0.9, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=13782
# CVM=0.9, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=17611
# CVM=0.9, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=18658
# CVM=0.9, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=18922
# CVM=0.91, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=5976
# CVM=0.91, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=13505
# CVM=0.91, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=17334
# CVM=0.91, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=18381
# CVM=0.91, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=18645
# CVM=0.92, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=5651
# CVM=0.92, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=13180
# CVM=0.92, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=17009
# CVM=0.92, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=18056
# CVM=0.92, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=18320
# CVM=0.93, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=5266
# CVM=0.93, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=12795
# CVM=0.93, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=16624
# CVM=0.93, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=17671
# CVM=0.93, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=17935
# CVM=0.94, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=4799
# CVM=0.94, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=12328
# CVM=0.94, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=16157
# CVM=0.94, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=17204
# CVM=0.94, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=17468
# CVM=0.95, CFM=0.1
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=4215
# CVM=0.95, CFM=0.2
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=11744
# CVM=0.95, CFM=0.3
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=15573
# CVM=0.95, CFM=0.4
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=16620
# CVM=0.95, CFM=0.5
# column norm matrix shape (303, 303)
# df_thresh_values.shape[0]=16884
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/cvm_sensitivity.pdf exists and override
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/cfm_sensitivity.pdf exists and override

# %%
from network.kpm_evaluation_metrics_cross import KPMEvaluator
from utils.params import KPNParams
kpn_parms = KPNParams(
    disciplines=[],
    row_normalize=False,
    threshold_mode='value_count_limit',
    quantile_threshold=0.65,
    cvm_threshold=0.95,
    cfm_threshold=0.2,
    matrix_filter=True,
    matrix_imshow=False,
    graph_show=True,
    layout="graphviz",
    save_kpn=True,
    old_matrix_version=False
)
generator = KPMEvaluator(kpn_parms = kpn_parms, sub_discipline = False)
df_results_degree_resolution = generator.calculate_precision_recall(type= 'all_degree_resolution')
generator.plot_degree_resolution_sensitivity(df_results_degree_resolution)
# Out:
# Successfully loaded Word2Vec model with dimension: 24
# Successfully loaded Word2Vec model with dimension: 24
# Successfully loaded Word2Vec model with dimension: 24
# Using filename pattern with name: precision_recall_results_all_degree_resolution.csv
# Cache file: /data/OpenAlex-Analysis/KPN-Mining/files/data/precision_recall_results_all_degree_resolution.csv
# Loading from cache: /data/OpenAlex-Analysis/KPN-Mining/files/data/precision_recall_results_all_degree_resolution.csv
# Loading cached data from /data/OpenAlex-Analysis/KPN-Mining/files/data/precision_recall_results_all_degree_resolution.csv
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/sensitivity_degree_resolution.pdf exists and override
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/sensitivity_resolution_degree.pdf exists and override

# %%
from network.kpm_evaluation_metrics_cross import KPMEvaluator
from utils.params import KPNParams
kpn_parms = KPNParams(
    disciplines=[],
    row_normalize=False,
    threshold_mode='value_count_limit',
    quantile_threshold=0.65,
    cvm_threshold=0.95,
    cfm_threshold=0.2,
    matrix_filter=True,
    matrix_imshow=False,
    graph_show=True,
    layout="graphviz",
    save_kpn=True,
    old_matrix_version=False
)
generator = KPMEvaluator(kpn_parms = kpn_parms, sub_discipline = False)
df_results_degree_resolution = generator.calculate_precision_recall(type= 'all_degree_resolution')

generator.plot_degree_resolution_f1_sensitivity(df_results_degree_resolution)
# Out:
# Successfully loaded Word2Vec model with dimension: 24
# Successfully loaded Word2Vec model with dimension: 24
# Successfully loaded Word2Vec model with dimension: 24
# Using filename pattern with name: precision_recall_results_all_degree_resolution.csv
# Cache file: /data/OpenAlex-Analysis/KPN-Mining/files/data/precision_recall_results_all_degree_resolution.csv
# Loading from cache: /data/OpenAlex-Analysis/KPN-Mining/files/data/precision_recall_results_all_degree_resolution.csv
# Loading cached data from /data/OpenAlex-Analysis/KPN-Mining/files/data/precision_recall_results_all_degree_resolution.csv
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/sensitivity_degree_resolution_f1.pdf exists and override
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/sensitivity_resolution_degree_f1.pdf exists and override

# %%
from network.kpm_evaluation_metrics_cross import KPMEvaluator
from utils.params import KPNParams
kpn_parms = KPNParams(
    disciplines=[],
    row_normalize=False,
    threshold_mode='value_count_limit',
    quantile_threshold=0.65,
    cvm_threshold=0.95,
    cfm_threshold=0.2,
    matrix_filter=True,
    matrix_imshow=False,
    graph_show=True,
    layout="graphviz",
    save_kpn=True,
    old_matrix_version=False
)
generator = KPMEvaluator(kpn_parms = kpn_parms, sub_discipline = False)
df_aucs = generator.calculate_auc_by_groups()
generator.plot_degree_resolution_sensitivity_auc(df_aucs, value_type='count')
# Out:
# Successfully loaded Word2Vec model with dimension: 24
# Successfully loaded Word2Vec model with dimension: 24
# Successfully loaded Word2Vec model with dimension: 24
# Using filename pattern with name: df_aucs_degree_resolution_sensitivity_evaluation.csv
# Cache file: /data/OpenAlex-Analysis/KPN-Mining/files/data/df_aucs_degree_resolution_sensitivity_evaluation.csv
# Loading from cache: /data/OpenAlex-Analysis/KPN-Mining/files/data/df_aucs_degree_resolution_sensitivity_evaluation.csv
# Loading cached data from /data/OpenAlex-Analysis/KPN-Mining/files/data/df_aucs_degree_resolution_sensitivity_evaluation.csv
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/sensitivity_degree_resolution_auc_count.pdf exists and override
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/sensitivity_resolution_degree_auc_count.pdf exists and override
