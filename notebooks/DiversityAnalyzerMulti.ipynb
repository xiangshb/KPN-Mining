# %%
from network.diversity_analysis_multi import DiversityAnalyzer
analyzer = DiversityAnalyzer(debugging=True)

# Analyze all authors with multiple windows  # -1 for cumulative
results = analyzer.analyze_all_authors(windows=[1, 3, 5, -1], parallel=True, skip_cache = False)

font_size_dict = {'title': 20, 'xlabel': 16, 'ylabel': 16, 'xtick': 16, 'ytick': 16, 'legend': 14, 'text': 14}
# Generate all plots
analyzer.plot_cumulative_unique_concepts_with_window(results, window = 3, figsize=(5, 5), font_size_dict=font_size_dict, save_fig=True)
# Out:
# Using instance cache directory: /data/files/prerequisite-learning-files/Concepts/NewSequences
# Using exact filename pattern: diversity_results_debugging_v1.pkl
# Cache file: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading from cache: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading cached data from /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# 2025-06-10 09:56:37,449 - network.diversity_analysis_multi - INFO - Plotting cumulative unique concepts for 11491 authors with ≥10 works
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/cumulative_unique_concepts_window3.pdf exists and override

# %%
from network.diversity_analysis_multi import DiversityAnalyzer
analyzer = DiversityAnalyzer(debugging=True)

# Analyze all authors with multiple windows  # -1 for cumulative
results = analyzer.analyze_all_authors(windows=[1, 3, 5, -1], parallel=True, skip_cache = False)

font_size_dict = {'title': 20, 'xlabel': 16, 'ylabel': 16, 'xtick': 16, 'ytick': 16, 'legend': 12, 'text': 14}
# Generate all plots
analyzer.plot_diversity_metrics_boxplot_comparison(results, metric_type = 'unique_counts', figsize=(5, 3), font_size_dict=font_size_dict, save_fig=True, selected_orders = [6, 10, 15, 20, 25, 30])
# Out:
# Using instance cache directory: /data/files/prerequisite-learning-files/Concepts/NewSequences
# Using exact filename pattern: diversity_results_debugging_v1.pkl
# Cache file: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading from cache: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading cached data from /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# 2025-06-10 12:03:03,986 - network.diversity_analysis_multi - INFO - Plotting boxplot for 4856 authors with ≥30 works
# 2025-06-10 12:03:03,987 - network.diversity_analysis_multi - INFO - Plotting selected publication orders: [6, 10, 15, 20, 25, 30]
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/unique_counts_boxplot_comparison.pdf exists and override

# %%
from network.diversity_analysis_multi import DiversityAnalyzer
analyzer = DiversityAnalyzer(debugging=True)

# Analyze all authors with multiple windows  # -1 for cumulative
results = analyzer.analyze_all_authors(windows=[1, 3, 5, -1], parallel=True, skip_cache = False)

font_size_dict = {'title': 20, 'xlabel': 16, 'ylabel': 16, 'xtick': 16, 'ytick': 16, 'legend': 14, 'text': 14}
# Generate all plots
analyzer.plot_diversity_metrics_boxplot_comparison(results, metric_type = 'entropies', figsize=(5, 3), font_size_dict=font_size_dict, save_fig=True, show_legend = False, selected_orders = [6, 10, 15, 20, 25, 30])
# Out:
# Using instance cache directory: /data/files/prerequisite-learning-files/Concepts/NewSequences
# Using exact filename pattern: diversity_results_debugging_v1.pkl
# Cache file: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading from cache: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading cached data from /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# 2025-06-10 12:02:52,487 - network.diversity_analysis_multi - INFO - Plotting boxplot for 4856 authors with ≥30 works
# 2025-06-10 12:02:52,489 - network.diversity_analysis_multi - INFO - Plotting selected publication orders: [6, 10, 15, 20, 25, 30]
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/entropies_boxplot_comparison.pdf exists and override

# %%
from network.diversity_analysis_multi import DiversityAnalyzer
analyzer = DiversityAnalyzer(debugging=True)

# Analyze all authors with multiple windows  # -1 for cumulative
results = analyzer.analyze_all_authors(windows=[1, 3, 5, -1], parallel=True, skip_cache = False)

font_size_dict = {'title': 20, 'xlabel': 16, 'ylabel': 16, 'xtick': 16, 'ytick': 16, 'legend': 14, 'text': 14}
# Generate all plots
analyzer.plot_diversity_metrics_boxplot_comparison(results, metric_type = 'hhis', figsize=(5, 3), font_size_dict=font_size_dict, save_fig=True, show_legend = False, selected_orders = [6, 10, 15, 20, 25, 30])
# Out:
# Using instance cache directory: /data/files/prerequisite-learning-files/Concepts/NewSequences
# Using exact filename pattern: diversity_results_debugging_v1.pkl
# Cache file: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading from cache: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading cached data from /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# 2025-06-10 12:02:09,802 - network.diversity_analysis_multi - INFO - Plotting boxplot for 4856 authors with ≥30 works
# 2025-06-10 12:02:09,803 - network.diversity_analysis_multi - INFO - Plotting selected publication orders: [6, 10, 15, 20, 25, 30]
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/hhis_boxplot_comparison.pdf exists and override

# %%
from network.diversity_analysis_multi import DiversityAnalyzer
analyzer = DiversityAnalyzer(debugging=True)

# Analyze all authors with multiple windows  # -1 for cumulative
results = analyzer.analyze_all_authors(windows=[1, 3, 5, -1], parallel=True, skip_cache = False)

font_size_dict = {'title': 20, 'xlabel': 16, 'ylabel': 16, 'xtick': 16, 'ytick': 16, 'legend': 14, 'text': 14}
# Generate all plots
analyzer.plot_entropy_comparison(results, figsize=(5, 5), window_size=3, font_size_dict=font_size_dict, save_fig=True)
# Out:
# Using instance cache directory: /data/files/prerequisite-learning-files/Concepts/NewSequences
# Using exact filename pattern: diversity_results_debugging_v1.pkl
# Cache file: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading from cache: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading cached data from /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# 2025-06-10 09:56:30,237 - network.diversity_analysis_multi - INFO - Plotting entropy comparison for 12299 authors with ≥8 works
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/entropy_comparison_window_3.pdf exists and override

# %%
from network.diversity_analysis_multi import DiversityAnalyzer
analyzer = DiversityAnalyzer(debugging=True)

# Analyze all authors with multiple windows  # -1 for cumulative
results = analyzer.analyze_all_authors(windows=[1, 3, 5, -1], parallel=True, skip_cache = False)

font_size_dict = {'title': 20, 'xlabel': 16, 'ylabel': 16, 'xtick': 16, 'ytick': 16, 'legend': 14, 'text': 14}
# Generate all plots
analyzer.plot_cumulative_hhi_with_window(results, window_size = 3, figsize=(5, 5), font_size_dict=font_size_dict, save_fig=True)
# Out:
# Using instance cache directory: /data/files/prerequisite-learning-files/Concepts/NewSequences
# Using exact filename pattern: diversity_results_debugging_v1.pkl
# Cache file: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading from cache: /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# Loading cached data from /data/files/prerequisite-learning-files/Concepts/NewSequences/diversity_results_debugging_v1.pkl
# 2025-06-10 09:56:21,509 - network.diversity_analysis_multi - INFO - Plotting HHI comparison for 12299 authors with ≥8 works
# file: /data/OpenAlex-Analysis/KPN-Mining/files/figures/cumulative_hhi_window_3.pdf exists and override
