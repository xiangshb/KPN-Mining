# %%
from network.sub_discipline_evaluation import SubFieldEvaluator

evaluator = SubFieldEvaluator()
result_df = evaluator.cross_sub_field_validation()
# Out:
# Loading existing data from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/all_authors_precision_sub_concepts.parquet
# collect_all_precision_data completed in 2.448s

# %%
# Visualize results
evaluator._visualize_precision_heatmap(result_df)
# Out:
# pdf file save at /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/precision_heatmap_by_discipline.pdf

# %%
# Visualize results
evaluator._visualize_precision_violins(result_df)
# Out:
# pdf file save at /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/precision_distribution_violin_plots.pdf

# %%
from network.period_evaluation import PeriodEvaluator
evaluator = PeriodEvaluator()
result_df = evaluator.plot_precision_by_period_connected(test = False)
# Out:
# Loading existing data from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/all_authors_period_precision.parquet
# collect_all_precision_data_period completed in 12.687s
# Figure saved to /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/precision_by_period_violin.pdf

# %%
from network.period_evaluation import PeriodEvaluator

evaluator = PeriodEvaluator()
evaluator.plot_precision_differences_by_period(test=False)
# Out:
# Figure saved to /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/precision_period_differences.pdf

# %%
from network.kpm_evaluation import KPMEvaluator

evaluator = KPMEvaluator(sub_concepts = True)
evaluator.plot_roc_curves_by_discipline(type='wcr', value_type='count', fig_size = (15, 4), save_fig = True, font_size = 16)
# Out:
# 2025-05-09 16:11:55,417 - gensim.utils - INFO - loading Word2Vec object from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model
# 2025-05-09 16:11:55,588 - gensim.utils - INFO - loading wv recursively from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model.wv.* with mmap=None
# 2025-05-09 16:11:55,589 - gensim.utils - INFO - setting ignored attribute cum_table to None
# 2025-05-09 16:11:55,923 - gensim.utils - INFO - Word2Vec lifecycle event {'fname': '/data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model', 'datetime': '2025-05-09T16:11:55.923351', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:26:10) \n[GCC 11.2.0]', 'platform': 'Linux-3.10.0-1160.62.1.el7.x86_64-x86_64-with-glibc2.17', 'event': 'loaded'}
# ...

# %%
from network.kpm_evaluation import KPMEvaluator

evaluator = KPMEvaluator(sub_concepts = True)
evaluator.plot_roc_curves_by_discipline(type='period', value_type='count', fig_size = (11, 3), save_fig = True)
# Out:
# 2025-05-09 16:04:22,286 - gensim.utils - INFO - loading Word2Vec object from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model
# 2025-05-09 16:04:22,453 - gensim.utils - INFO - loading wv recursively from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model.wv.* with mmap=None
# 2025-05-09 16:04:22,454 - gensim.utils - INFO - setting ignored attribute cum_table to None
# 2025-05-09 16:04:22,881 - gensim.utils - INFO - Word2Vec lifecycle event {'fname': '/data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model', 'datetime': '2025-05-09T16:04:22.881669', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:26:10) \n[GCC 11.2.0]', 'platform': 'Linux-3.10.0-1160.62.1.el7.x86_64-x86_64-with-glibc2.17', 'event': 'loaded'}
# ...

# %%
from network.kpm_evaluation import KPMEvaluator

evaluator = KPMEvaluator(sub_concepts = True)
evaluator.plot_pr_curves_by_discipline(type='wcr', value_type='count', fig_size = (15, 4), save_fig = True, font_size = 16)
# Out:
# 2025-05-09 16:27:39,356 - gensim.utils - INFO - loading Word2Vec object from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model
# 2025-05-09 16:27:39,522 - gensim.utils - INFO - loading wv recursively from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model.wv.* with mmap=None
# 2025-05-09 16:27:39,523 - gensim.utils - INFO - setting ignored attribute cum_table to None
# 2025-05-09 16:27:39,877 - gensim.utils - INFO - Word2Vec lifecycle event {'fname': '/data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model', 'datetime': '2025-05-09T16:27:39.876967', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:26:10) \n[GCC 11.2.0]', 'platform': 'Linux-3.10.0-1160.62.1.el7.x86_64-x86_64-with-glibc2.17', 'event': 'loaded'}
# ...

# %%
from network.kpm_evaluation import KPMEvaluator

evaluator = KPMEvaluator(sub_concepts = True)
evaluator.plot_pr_curves_by_discipline(type='period', value_type='count', fig_size = (12, 3), save_fig = True, font_size = 14)
# Out:
# 2025-05-09 16:29:23,634 - gensim.utils - INFO - loading Word2Vec object from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model
# 2025-05-09 16:29:23,871 - gensim.utils - INFO - loading wv recursively from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model.wv.* with mmap=None
# 2025-05-09 16:29:23,872 - gensim.utils - INFO - setting ignored attribute cum_table to None
# 2025-05-09 16:29:24,307 - gensim.utils - INFO - Word2Vec lifecycle event {'fname': '/data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model', 'datetime': '2025-05-09T16:29:24.307446', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:26:10) \n[GCC 11.2.0]', 'platform': 'Linux-3.10.0-1160.62.1.el7.x86_64-x86_64-with-glibc2.17', 'event': 'loaded'}
# ...

# %%
from network.kpm_evaluation import KPMEvaluator

evaluator = KPMEvaluator(sub_concepts = False)
evaluator.plot_roc_curves_by_cross_discipline(type='wcr', value_type='count', fig_size = (4, 3.8), save_fig = True, font_size = 14)
# Out:
# 2025-05-09 17:14:27,561 - gensim.utils - INFO - loading Word2Vec object from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model
# 2025-05-09 17:14:27,790 - gensim.utils - INFO - loading wv recursively from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model.wv.* with mmap=None
# 2025-05-09 17:14:27,791 - gensim.utils - INFO - setting ignored attribute cum_table to None
# 2025-05-09 17:14:28,222 - gensim.utils - INFO - Word2Vec lifecycle event {'fname': '/data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model', 'datetime': '2025-05-09T17:14:28.221965', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:26:10) \n[GCC 11.2.0]', 'platform': 'Linux-3.10.0-1160.62.1.el7.x86_64-x86_64-with-glibc2.17', 'event': 'loaded'}
# ...

# %%
from network.kpm_evaluation import KPMEvaluator

evaluator = KPMEvaluator(sub_concepts = False)
evaluator.plot_roc_curves_by_cross_discipline(type='period', value_type='count', fig_size = (4, 3.8), save_fig = True, font_size = 14)
# Out:
# 2025-05-09 17:14:18,622 - gensim.utils - INFO - loading Word2Vec object from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model
# 2025-05-09 17:14:18,882 - gensim.utils - INFO - loading wv recursively from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model.wv.* with mmap=None
# 2025-05-09 17:14:18,883 - gensim.utils - INFO - setting ignored attribute cum_table to None
# 2025-05-09 17:14:19,291 - gensim.utils - INFO - Word2Vec lifecycle event {'fname': '/data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/Word2Vec_dim_24_epoch_100.model', 'datetime': '2025-05-09T17:14:19.291924', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:26:10) \n[GCC 11.2.0]', 'platform': 'Linux-3.10.0-1160.62.1.el7.x86_64-x86_64-with-glibc2.17', 'event': 'loaded'}
# ...
