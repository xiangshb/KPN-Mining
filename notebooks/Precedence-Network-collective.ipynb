# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_concept_flow_matrix
openalex_dataset = Dataset()
openalex_dataset.concept_flow_matrix_analysis(params = Params_community_concept_pairs(concept_level = 1, less_than = False, select_mode = 'all'),
                                concept_flow_params = Params_concept_flow_matrix(disciplines = ['Mathematics'], row_normalize=False, matrix_value_cumsum_ratio = 0.95, matrix_value_count_cumsum_ratio=0.2, 
                                                                                              matrix_filter = True, matrix_imshow = True, graph_show=True, layout = "graphviz", save_G_concept_flow = False, 
                                                                                              old_matrix_version = False)) # 'Computer science'
# Out:
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/level_1_concepts.csv exists and override
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/figures/flow_Mathematics_Mathematics_matrix_plot.pdf exists and override
# column norm matrix shape (16, 16)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.95 to large
# filter only by matrix_value_count_cumsum_ratio=0.2
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/figures/flow_Mathematics_Mathematics_matrix_plot_column_norm.pdf exists and override
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Mathematics_column_norm_edges.csv exists and override
# nodes 15
# edge shape (51, 3)
# Graph nodes 15
# Graph edges 51
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Mathematics_column_norm_nodes.csv exists and override
# Function get_network_layout_position took 0.030s to run.

# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_concept_flow_matrix
openalex_dataset = Dataset()
openalex_dataset.concept_flow_matrix_analysis(params = Params_community_concept_pairs(concept_level = 1, less_than = False, select_mode = 'all'),
                                concept_flow_params = Params_concept_flow_matrix(disciplines = ['Biology'], row_normalize=False, matrix_value_cumsum_ratio = 0.95, matrix_value_count_cumsum_ratio=0.08, 
                                                                                              matrix_filter = True, matrix_imshow = False, graph_show=True, layout = "graphviz", save_G_concept_flow = False, 
                                                                                              save_G_edges_nodes_csv = True, old_matrix_version = False)) # 'Computer science'
# Out:
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/level_1_concepts.csv exists and override
# column norm matrix shape (32, 32)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.95 to large
# filter only by matrix_value_count_cumsum_ratio=0.08
# nodes 23
# edge shape (81, 3)
# Graph nodes 23
# Graph edges 81
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Biology_column_norm_edges.csv exists and override
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Biology_column_norm_nodes.csv exists and override
# Function get_network_layout_position took 0.037s to run.

# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_concept_flow_matrix
openalex_dataset = Dataset()
openalex_dataset.concept_flow_matrix_analysis(params = Params_community_concept_pairs(concept_level = 1, less_than = False, select_mode = 'all'),
                                concept_flow_params = Params_concept_flow_matrix(disciplines = ['Philosophy', 'History', 'Art'], row_normalize=False, matrix_value_cumsum_ratio = 0.99, matrix_value_count_cumsum_ratio=0.3, 
                                                                                              matrix_filter = True, matrix_imshow = False, graph_show=True, layout = "graphviz", save_G_concept_flow = False, 
                                                                                              save_G_edges_nodes_csv = True, old_matrix_version = False)) # 'Computer science'
# Out:
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/level_1_concepts.csv exists and override
# column norm matrix shape (13, 13)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.99 to large
# filter only by matrix_value_count_cumsum_ratio=0.3
# nodes 13
# edge shape (50, 3)
# Graph nodes 13
# Graph edges 50
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Art_History_Philosophy_column_norm_edges.csv exists and override
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Art_History_Philosophy_column_norm_nodes.csv exists and override
# Function get_network_layout_position took 0.032s to run.

# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_concept_flow_matrix
openalex_dataset = Dataset()
openalex_dataset.concept_flow_matrix_analysis(params = Params_community_concept_pairs(concept_level = 1, less_than = False, select_mode = 'all'),
                                concept_flow_params = Params_concept_flow_matrix(disciplines = ['Sociology', 'Political science', 'Psychology'], row_normalize=False, matrix_value_cumsum_ratio = 0.99, matrix_value_count_cumsum_ratio=0.25, 
                                                                                              matrix_filter = True, matrix_imshow = False, graph_show=True, layout = "graphviz", save_G_concept_flow = False, 
                                                                                              save_G_edges_nodes_csv = True, old_matrix_version = False)) # 'Computer science'
# Out:
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/level_1_concepts.csv exists and override
# column norm matrix shape (18, 18)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.99 to large
# filter only by matrix_value_count_cumsum_ratio=0.25
# nodes 17
# edge shape (81, 3)
# Graph nodes 17
# Graph edges 81
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Political_science_Psychology_Sociology_column_norm_edges.csv exists and override
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Political_science_Psychology_Sociology_column_norm_nodes.csv exists and override
# Function get_network_layout_position took 0.037s to run.

# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_concept_flow_matrix
openalex_dataset = Dataset()
openalex_dataset.concept_flow_matrix_analysis(params = Params_community_concept_pairs(concept_level = 1, less_than = False, select_mode = 'all'),
                                concept_flow_params = Params_concept_flow_matrix(disciplines = ['Economics', 'Business'], row_normalize=False, matrix_value_cumsum_ratio = 0.99, matrix_value_count_cumsum_ratio=0.15, 
                                                                                              matrix_filter = True, matrix_imshow = False, graph_show=True, layout = "graphviz", save_G_concept_flow = False, 
                                                                                              save_G_edges_nodes_csv = True, old_matrix_version = False)) # 'Computer science'
# Out:
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/level_1_concepts.csv exists and override
# column norm matrix shape (30, 11)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.99 to large
# filter only by matrix_value_count_cumsum_ratio=0.15
# column norm matrix shape (11, 30)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.99 to large
# filter only by matrix_value_count_cumsum_ratio=0.15
# nodes 26
# edge shape (88, 3)
# Graph nodes 26
# Graph edges 88
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Business_Economics_column_norm_edges.csv exists and override
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Business_Economics_column_norm_nodes.csv exists and override
# Function get_network_layout_position took 0.042s to run.

# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_concept_flow_matrix
openalex_dataset = Dataset()
openalex_dataset.concept_flow_matrix_analysis(params = Params_community_concept_pairs(concept_level = 1, less_than = False, select_mode = 'all'),
                                concept_flow_params = Params_concept_flow_matrix(disciplines = ['Geography', 'Geology', 'Environmental science'], row_normalize=False, matrix_value_cumsum_ratio = 0.99, matrix_value_count_cumsum_ratio=0.25, 
                                                                                              matrix_filter = True, matrix_imshow = False, graph_show=True, layout = "graphviz", save_G_concept_flow = False, 
                                                                                              save_G_edges_nodes_csv = True, old_matrix_version = False)) # 'Computer science'
# Out:
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/level_1_concepts.csv exists and override
# column norm matrix shape (16, 16)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.99 to large
# filter only by matrix_value_count_cumsum_ratio=0.25
# nodes 16
# edge shape (64, 3)
# Graph nodes 16
# Graph edges 64
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Environmental_science_Geography_Geology_column_norm_edges.csv exists and override
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Environmental_science_Geography_Geology_column_norm_nodes.csv exists and override
# Function get_network_layout_position took 0.024s to run.

# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_concept_flow_matrix
openalex_dataset = Dataset()
openalex_dataset.concept_flow_matrix_analysis(params = Params_community_concept_pairs(concept_level = 1, less_than = False, select_mode = 'all'),
                                concept_flow_params = Params_concept_flow_matrix(disciplines = ['Biology', 'Medicine'], row_normalize=False, matrix_value_cumsum_ratio = 0.99, matrix_value_count_cumsum_ratio=0.05, 
                                                                                              matrix_filter = True, matrix_imshow = False, graph_show=True, layout = "graphviz", save_G_concept_flow = False, 
                                                                                              save_G_edges_nodes_csv = True, old_matrix_version = False)) # 'Computer science'
# Out:
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/level_1_concepts.csv exists and override
# column norm matrix shape (25, 40)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.99 to large
# filter only by matrix_value_count_cumsum_ratio=0.05
# column norm matrix shape (40, 25)
# df_thresh_values.shape[0]=0
# matrix_value_cumsum_ratio = 0.99 to large
# filter only by matrix_value_count_cumsum_ratio=0.05
# nodes 29
# edge shape (93, 3)
# Graph nodes 29
# Graph edges 93
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Biology_Medicine_column_norm_edges.csv exists and override
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/edges/Biology_Medicine_column_norm_nodes.csv exists and override
# Function get_network_layout_position took 0.045s to run.
