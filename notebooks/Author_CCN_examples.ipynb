# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_community_visualization
openalex_dataset = Dataset()
df_concept_pairs = openalex_dataset.get_author_CCN_community(from_selected = False, iter_i = 0, k_th = 5800, 
                    params = Params_community_concept_pairs(community_method = 'louvain', min_community_size = 2, min_community_filter_size = 8, min_concept_size = 1, max_concept_size = 5, 
                                                            select_mode = 'collective', work_coverage_filter_ratio = 0.9, work_coverage_ratio = 0.8, concept_level = 1),

                    visual_params = Params_community_visualization(show_community = True, show_n_pubs_by_community = True, show_legend = False, n_col = 3,layout='graphviz',
                                                                    rescale_layout = True, bbox_to_anchor = (0.8, 0.85), save_pdf = True, override=True, axis_off=True, pad_inches = 1, 
                                                                    subplots_adjust = {'effective': True, 'left':0.2, 'right':0.8, 'top':0.7, 'bottom':0.3}, 
                                                                    paddings_adjust={'effective': False, 'w_pad':-10, 'h_pad':-10})) # step 2.3
# Out:
# Function get_author_communities took 0.032s to run.
# Function get_CCN_temporal_community_pairs took 0.110s to run.
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/figures/A111448884_bar_n_community_pubs_by_year.pdf exists and override
# file: ../../../data/files/prerequisite-learning-files/Concepts/A111448884_concept_pairs.csv exists and override
# coordinates rescaled
# Function get_network_layout_position took 0.481s to run.
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/figures/A111448884_CCN_louvain_min_community_size_2.pdf exists and override

# %%
from dataset import Dataset
from param_class import Params_community_concept_pairs, Params_community_visualization
openalex_dataset = Dataset()
df_concept_pairs = openalex_dataset.get_author_CCN_community(from_selected = True, discipline = None, i_th = 101, 
                    params = Params_community_concept_pairs(community_method = 'louvain', min_community_size = 2, min_community_filter_size = 8, min_concept_size = 1, max_concept_size = 5, 
                                                            select_mode = 'collective', work_coverage_filter_ratio = 0.9, work_coverage_ratio = 0.8, concept_level = 1),

                    visual_params = Params_community_visualization(show_community = True, show_n_pubs_by_community = True, show_legend = False, n_col = 3,layout='graphviz',
                                                                    rescale_layout = False, bbox_to_anchor = (0.8, 0.85), save_pdf = True, override=True, axis_off=True, pad_inches = 1, 
                                                                    subplots_adjust = {'effective': False, 'left':0.1, 'right':0.9, 'top':0.9, 'bottom':0.3}, 
                                                                    paddings_adjust={'effective': False, 'w_pad':-10, 'h_pad':-10})) # step 2.3
# Out:
# Function get_author_communities took 0.042s to run.
# Function get_CCN_temporal_community_pairs took 0.157s to run.
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/figures/A102994422_bar_n_community_pubs_by_year.pdf exists and override
# file: ../../../data/files/prerequisite-learning-files/Concepts/A102994422_concept_pairs.csv exists and override
# Function get_network_layout_position took 6.021s to run.
# file: /home/OpenAlex-Analysis/Prerequisite-Learning/files/figures/A102994422_CCN_louvain_min_community_size_2.pdf exists and override
