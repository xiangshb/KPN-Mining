# %%
# Import the evaluator
from network.individual_researcher_evaluation import IndividualEvaluator

# Create an evaluator instance
evaluator = IndividualEvaluator()

# Method 2: Execute step by step
# Collect precision data from all batches
df = evaluator.collect_all_precision_data()
# Out:
# Loading existing data from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/all_authors_precision.parquet
# collect_all_precision_data completed in 2.968s

# %%
# Import the evaluator
from network.individual_researcher_evaluation import IndividualEvaluator

# Create an evaluator instance
evaluator = IndividualEvaluator()

# Method 2: Execute step by step
# Collect precision data from all batches
df = evaluator.collect_all_precision_data()

evaluator.analyze_tcp_ratio_under_various_precisions(df) #
# Out:
# Loading existing data from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/all_authors_precision.parquet
# collect_all_precision_data completed in 2.786s
# file: /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/pair_pdf_by_precision_across_wcr.pdf exists and override

# %%
# Import the evaluator
from network.individual_researcher_evaluation import IndividualEvaluator

# Create an evaluator instance
evaluator = IndividualEvaluator()

# Method 2: Execute step by step
# Collect precision data from all batches
df = evaluator.collect_all_precision_data()

data = evaluator.analyze_precision_by_wcr(df, colors = [
            # '#1b9e77',  # Dark green from 'Greens'
            # '#4575b4',  # Medium blue from 'Blues'
            '#ff7f00',  # Orange from 'Oranges'
            '#73c2fb',  # Light blue from 'PuBuGn'
            # '#41b6c4',  # Teal from 'YlGnBu'
            # '#8856a7',   # Purple from 'Purples'
            
            # '#d73027',  # Brick red (RdYlBu)
            # '#fc8d59',  # Salmon (RdYlBu)
            '#91cf60',  # Lime green (RdYlGn)
            # '#5e3c99',  # Deep purple (PuOr)
            # '#e6ab02',  # Gold (PiYG)
            # '#66a61e',  # Olive green (Set2)
            '#6a3d9a',  # Royal purple (Set1)
            '#33a02c',   # Forest green (Set1)
            '#e7298a',  # Magenta (Set2)
        ]) # ['#ff7f0e', '#1f77b4', '#2ca02c', '#d62728', '#9467bd', '#8c564b']['Greens', 'Blues', 'PuBuGn', 'Oranges', 'YlGnBu', 'Purples']
# Out:
# Loading existing data from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/all_authors_precision.parquet
# collect_all_precision_data completed in 3.031s
# file: /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/precision_categories_trend_by_wcr.pdf exists and override

# %%
# Import the evaluator
from network.individual_researcher_evaluation import IndividualEvaluator

# Create an evaluator instance
evaluator = IndividualEvaluator()

# Method 2: Execute step by step
# Collect precision data from all batches
df = evaluator.collect_all_precision_data()

evaluator.plot_precision_cdfs(df)
# Out:
# Loading existing data from /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/all_authors_precision.parquet
# collect_all_precision_data completed in 2.727s
# Precision_1 effective authors 4969403
# Precision_0.95 effective authors 4969403
# Precision_0.9 effective authors 4969403
# Precision_0.85 effective authors 4969403
# Precision_0.8 effective authors 4969403
# Precision_0.75 effective authors 4969403
# Precision_0.7 effective authors 4969403
# Precision_0.65 effective authors 4969403
# Precision_0.6 effective authors 4969403
# Figure saved to /data/shentt/XIANGSHB/KPN-Mining/prerequisite-learning-files/CCNs/analysis/precision_cdf_subplots.pdf
